# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
#Carga desde un archivo .csv sin índice
data = pd.read_csv('Porto_Portugal.csv')
data.head(5)
# Out:
#    Unnamed: 0      id                                            name  \
# 0           0   46609                               Byron Beach Cabin
# 1           1   59459                              Tea on the Terrace
# 2           2  111036      5 Star Luxury @ Tweed Coast - Salt Village
# 3           3  113407  Byron Bay Hinterland House & Pool POCKET PINES
# 4           4  259951                              Rosebank Farmhouse
#
#    host_id  host_name  host_since host_response_time host_response_rate  \
# 0   208641       Glen  2010-08-21     within an hour               100%
# 1   285576        Liz  2010-11-12     within an hour               100%
# 2   569563     Tricia  2011-05-09     within an hour               100%
# 3   576938         Jo  2011-05-10     within an hour               100%
# 4  1340489  Ann-Marie  2011-10-27     within an hour               100%
#
#   host_acceptance_rate host_is_superhost  ...  review_scores_accuracy  \
# 0                  83%                 f  ...                    4.92
# 1                  93%                 t  ...                    4.93
# 2                  96%                 t  ...                    4.97
# 3                  95%                 t  ...                    4.88
# 4                 100%                 f  ...                    4.88
#
#   review_scores_cleanliness review_scores_checkin  \
# 0                      4.96                  5.00
# 1                      4.94                  4.94
# 2                      4.94                  4.84
# 3                      4.75                  4.96
# 4                      4.76                  5.00
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         5.00                    4.92                 4.77
# 1                         4.94                    4.80                 4.92
# 2                         4.92                    4.97                 4.88
# 3                         4.98                    4.88                 4.71
# 4                         5.00                    4.94                 4.71
#
#   instant_bookable calculated_host_listings_count  \
# 0                f                              1
# 1                f                              1
# 2                t                              1
# 3                f                              1
# 4                f                              1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            1
# 1                                            0
# 2                                            1
# 3                                            1
# 4                                            1
#
#    calculated_host_listings_count_private_rooms
# 0                                             0
# 1                                             1
# 2                                             0
# 3                                             0
# 4                                             0
#
# [5 rows x 51 columns]

# %%
#Eliminar columnas inncesarias
#axis = 1 para columnas
#axis = 0 para filas
data1 = data.drop(['Unnamed: 0'],axis=1)
data1
# Out:
#                        id                                            name  \
# 0                   46609                               Byron Beach Cabin
# 1                   59459                              Tea on the Terrace
# 2                  111036      5 Star Luxury @ Tweed Coast - Salt Village
# 3                  113407  Byron Bay Hinterland House & Pool POCKET PINES
# 4                  259951                              Rosebank Farmhouse
# ...                   ...                                             ...
# 6241  1309169243696998503                           Tweed Coastal Retreat
# 6242  1309580556361446644          13 William - Oceanstays - Pet Friendly
# 6243  1310599322159916197                                La Casita Studio
# 6244  1310616537700203937                                        Rachana.
# 6245  1310716580562175377                         Bayshore Bungalow No.14
#
#         host_id           host_name  host_since  host_response_time  \
# 0        208641                Glen  2010-08-21      within an hour
# 1        285576                 Liz  2010-11-12      within an hour
# 2        569563              Tricia  2011-05-09      within an hour
# 3        576938                  Jo  2011-05-10      within an hour
# 4       1340489           Ann-Marie  2011-10-27      within an hour
# ...         ...                 ...         ...                 ...
# 6241    8586213             Matthew  2013-09-02                 NaN
# 6242  498657660          Oceanstays  2023-01-30      within an hour
# 6243  472492532              Camila  2022-07-31                 NaN
# 6244  152421180  Your Luxury Escape  2017-09-28  within a few hours
# 6245  664353848               Naomi  2024-11-28      within an hour
#
#      host_response_rate host_acceptance_rate host_is_superhost  \
# 0                  100%                  83%                 f
# 1                  100%                  93%                 t
# 2                  100%                  96%                 t
# 3                  100%                  95%                 t
# 4                  100%                 100%                 f
# ...                 ...                  ...               ...
# 6241                NaN                  NaN                 f
# 6242               100%                  99%                 t
# 6243                NaN                  NaN                 f
# 6244                84%                  99%                 t
# 6245               100%                 100%                 f
#
#       host_listings_count  ... review_scores_accuracy  \
# 0                       1  ...                   4.92
# 1                       1  ...                   4.93
# 2                       1  ...                   4.97
# 3                       1  ...                   4.88
# 4                       1  ...                   4.88
# ...                   ...  ...                    ...
# 6241                    1  ...                    NaN
# 6242                   39  ...                    NaN
# 6243                    2  ...                    NaN
# 6244                   66  ...                    NaN
# 6245                   12  ...                    NaN
#
#      review_scores_cleanliness  review_scores_checkin  \
# 0                         4.96                   5.00
# 1                         4.94                   4.94
# 2                         4.94                   4.84
# 3                         4.75                   4.96
# 4                         4.76                   5.00
# ...                        ...                    ...
# 6241                       NaN                    NaN
# 6242                       NaN                    NaN
# 6243                       NaN                    NaN
# 6244                       NaN                    NaN
# 6245                       NaN                    NaN
#
#       review_scores_communication  review_scores_location review_scores_value  \
# 0                            5.00                    4.92                4.77
# 1                            4.94                    4.80                4.92
# 2                            4.92                    4.97                4.88
# 3                            4.98                    4.88                4.71
# 4                            5.00                    4.94                4.71
# ...                           ...                     ...                 ...
# 6241                          NaN                     NaN                 NaN
# 6242                          NaN                     NaN                 NaN
# 6243                          NaN                     NaN                 NaN
# 6244                          NaN                     NaN                 NaN
# 6245                          NaN                     NaN                 NaN
#
#      instant_bookable  calculated_host_listings_count  \
# 0                   f                               1
# 1                   f                               1
# 2                   t                               1
# 3                   f                               1
# 4                   f                               1
# ...               ...                             ...
# 6241                t                               1
# 6242                t                              39
# 6243                t                               1
# 6244                t                              66
# 6245                t                              12
#
#       calculated_host_listings_count_entire_homes  \
# 0                                               1
# 1                                               0
# 2                                               1
# 3                                               1
# 4                                               1
# ...                                           ...
# 6241                                            1
# 6242                                           39
# 6243                                            1
# 6244                                           61
# 6245                                           12
#
#      calculated_host_listings_count_private_rooms
# 0                                               0
# 1                                               1
# 2                                               0
# 3                                               0
# 4                                               0
# ...                                           ...
# 6241                                            0
# 6242                                            0
# 6243                                            0
# 6244                                            5
# 6245                                            0
#
# [6246 rows x 50 columns]

# %%
#Identificar valores nulos por columna
valores_nulos=data1.isnull().sum()
valores_nulos
# Out:
# id                                                 0
# name                                               0
# host_id                                            0
# host_name                                          0
# host_since                                         0
# host_response_time                               723
# host_response_rate                               723
# host_acceptance_rate                             518
# host_is_superhost                                104
# host_listings_count                                0
# host_identity_verified                             0
# neighbourhood_cleansed                             0
# neighbourhood_group_cleansed                    6246
# latitude                                           0
# longitude                                          0
# property_type                                      0
# room_type                                          0
# accommodates                                       0
# bathrooms                                        378
# bathrooms_text                                     0
# bedrooms                                          34
# beds                                             386
# price                                            378
# minimum_nights                                     0
# maximum_nights                                     0
# minimum_minimum_nights                             0
# maximum_minimum_nights                             0
# minimum_maximum_nights                             0
# maximum_maximum_nights                             0
# minimum_nights_avg_ntm                             0
# maximum_nights_avg_ntm                             0
# has_availability                                  35
# availability_30                                    0
# availability_60                                    0
# availability_90                                    0
# availability_365                                   0
# number_of_reviews                                  0
# number_of_reviews_ltm                              0
# number_of_reviews_l30d                             0
# review_scores_rating                            1085
# review_scores_accuracy                          1087
# review_scores_cleanliness                       1087
# review_scores_checkin                           1087
# review_scores_communication                     1087
# review_scores_location                          1087
# review_scores_value                             1087
# instant_bookable                                   0
# calculated_host_listings_count                     0
# calculated_host_listings_count_entire_homes        0
# calculated_host_listings_count_private_rooms       0
# dtype: int64

# %%
data3=data.copy()

# %% [markdown]
# Generar una función para cada una de las siguientes acciones:
#
#  a) Reemplazar valores nulos con el método de “mediana” en las columnas tipo “numeric (int y float)”
#
#  b) Reemplazar valores nulos con el método de “ffill” en las columnas tipo “object, datetime y category”
#
#  c) Reemplazar valores nulos con el método de “bfill” en las columnas tipo “object, datetime y category”
#
#  d) Reemplazar valores nulos con el método de “string concreto” en las columnas tipo “object, datetime y category”
#
#  e) Reemplazar valores nulos con el método de “constante” en las columnas tipo “numeric (int y float)”

# %%
def sust_prom(dataframe):
    #Separo columnas cuantitativas del dataframe
    cuantitativas_con_nulos = dataframe.select_dtypes(include=['float64', 'int64','float','int'])
    #Separo columnas cualitativas del dataframe
    cualitativas = dataframe.select_dtypes(include=['object', 'datetime','category'])
    #Sustituir valores nulos con promedio o media
    cuantitativas = cuantitativas_con_nulos.fillna(round(cuantitativas_con_nulos.mean(), 1))
    # Unimos el dataframe cuantitativo limpio con el dataframe cualitativo
    Datos_sin_nulos = pd.concat([cuantitativas, cualitativas], axis=1)
    
    return(Datos_sin_nulos)

def sust_ffill(dataframe):
    cuantitativas = dataframe.select_dtypes(include=['float64', 'int64','float','int'])
    cualitativas_con_nulos = dataframe.select_dtypes(include=['object', 'datetime','category'])
    cualitativas = cualitativas_con_nulos.fillna(method='ffill')
    Datos_sin_nulos = pd.concat([cuantitativas, cualitativas], axis=1)
    
    return(Datos_sin_nulos)

def sust_bfill(dataframe):
    cuantitativas = dataframe.select_dtypes(include=['float64', 'int64','float','int'])
    cualitativas_con_nulos = dataframe.select_dtypes(include=['object', 'datetime','category'])
    cualitativas = cualitativas_con_nulos.fillna(method='bfill')
    Datos_sin_nulos = pd.concat([cuantitativas, cualitativas], axis=1)
    
    return(Datos_sin_nulos)


def sust_string(dataframe,cadena):
    cuantitativas = dataframe.select_dtypes(include=['float64', 'int64','float','int'])
    cualitativas_con_nulos = dataframe.select_dtypes(include=['object', 'datetime','category'])
    cualitativas = cualitativas_con_nulos.fillna(cadena)
    Datos_sin_nulos = pd.concat([cuantitativas, cualitativas], axis=1)
    
    return(Datos_sin_nulos)

def sust_constante(dataframe,constante):
    cuantitativas_con_nulos = dataframe.select_dtypes(include=['float64', 'int64','float','int'])
    cualitativas = dataframe.select_dtypes(include=['object', 'datetime','category'])
    cuantitativas = cuantitativas_con_nulos.fillna(constante)
    Datos_sin_nulos = pd.concat([cuantitativas, cualitativas], axis=1)
    
    return(Datos_sin_nulos)

# %%
sust_mean = sust_prom(data3)
sust_mean.to_csv('sustitución_promedio.csv')
sust_mean.isnull().sum()

# %%
sust_forward = sust_ffill(data3)
sust_forward.to_csv('sustitución_ffill.csv')
sust_forward.isnull().sum()

# %%
sust_backward = sust_bfill(data3)
sust_backward.to_csv('sustitución_bfill.csv')
sust_backward.isnull().sum()

# %%
sust_cadena = sust_string(data3,'within a day')
sust_cadena.to_csv('sustitución_string.csv')
sust_cadena.isnull().sum()

# %%
sust_cons = sust_constante(data3,5)
sust_cons.to_csv('sustitución_constante.csv')
sust_cons.isnull().sum()
# Out:
# Unnamed: 0                                        0
# id                                                0
# host_id                                           0
# host_listings_count                               0
# neighbourhood_group_cleansed                      0
# latitude                                          0
# longitude                                         0
# accommodates                                      0
# bathrooms                                         0
# bedrooms                                          0
# beds                                              0
# minimum_nights                                    0
# maximum_nights                                    0
# minimum_minimum_nights                            0
# maximum_minimum_nights                            0
# minimum_maximum_nights                            0
# maximum_maximum_nights                            0
# minimum_nights_avg_ntm                            0
# maximum_nights_avg_ntm                            0
# availability_30                                   0
# availability_60                                   0
# availability_90                                   0
# availability_365                                  0
# number_of_reviews                                 0
# number_of_reviews_ltm                             0
# number_of_reviews_l30d                            0
# review_scores_rating                              0
# review_scores_accuracy                            0
# review_scores_cleanliness                         0
# review_scores_checkin                             0
# review_scores_communication                       0
# review_scores_location                            0
# review_scores_value                               0
# calculated_host_listings_count                    0
# calculated_host_listings_count_entire_homes       0
# calculated_host_listings_count_private_rooms      0
# name                                              0
# host_name                                         0
# host_since                                        0
# host_response_time                              723
# host_response_rate                              723
# host_acceptance_rate                            518
# host_is_superhost                               104
# host_identity_verified                            0
# neighbourhood_cleansed                            0
# property_type                                     0
# room_type                                         0
# bathrooms_text                                    0
# price                                           378
# has_availability                                 35
# instant_bookable                                  0
# dtype: int64
